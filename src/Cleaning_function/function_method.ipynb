# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
from src import cleaning_v3
df = pd.read_csv("data/attacks.csv",sep=',' ,encoding= 'latin_1')
print(df.columns)
df = cleaning_v3.Cleaning_function(df)
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\amirg\OneDrive\Documents\Iron hack\1_Data Analysis_Oktober\Projects\Project_I\main.ipynb Cell 2 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/amirg/OneDrive/Documents/Iron%20hack/1_Data%20Analysis_Oktober/Projects/Project_I/main.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> df = pd.read_csv("data/attacks.csv",sep=',' ,encoding= 'latin_1')
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df.sample(10)
# Out:
#         Case Number         Date    Year        Type Country          Area  \
# 21138           NaN          NaN     NaN         NaN     NaN           NaN
# 19445           NaN          NaN     NaN         NaN     NaN           NaN
# 11474           NaN          NaN     NaN         NaN     NaN           NaN
# 16633           NaN          NaN     NaN         NaN     NaN           NaN
# 5248     1921.08.22  22-Aug-1921  1921.0  Unprovoked   HAITI  Cape Haitien
# 13310           NaN          NaN     NaN         NaN     NaN           NaN
# 10658           NaN          NaN     NaN         NaN     NaN           NaN
# 24367           NaN          NaN     NaN         NaN     NaN           NaN
# 20409           NaN          NaN     NaN         NaN     NaN           NaN
# 1504   2006.02.01.b  01-Feb-2006  2006.0  Unprovoked   TONGA        Vava'u
#
#           Location                         Activity                  Name  \
# ...

# %% [markdown]
# #### bars, pie plots and some line plots \n
# #### ; para quitar comentarios
# #### autopct="%.1f%%" --> to put in percentage in the piechart
# #### different activities in the sharl attacks:
# ####      look at countries and surfers, boaters
# ####      what different types of sharks: stacked barplot
# ####      The most dangerous species
