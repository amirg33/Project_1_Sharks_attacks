# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import re
from cProfile import label

# %%
df = pd.read_csv("../data/shark_attack_cleaned.csv",sep=',' ,encoding= 'latin_1')
df = df.rename(columns={"index": "original_order"})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\amirg\OneDrive\Documents\Iron hack\1_Data Analysis_Oktober\Projects\Project_I\main.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/amirg/OneDrive/Documents/Iron%20hack/1_Data%20Analysis_Oktober/Projects/Project_I/main.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("../data/shark_attack_cleaned.csv",sep=',' ,encoding= 'latin_1')
#       <a href='vscode-notebook-cell:/c%3A/Users/amirg/OneDrive/Documents/Iron%20hack/1_Data%20Analysis_Oktober/Projects/Project_I/main.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df = df.rename(columns={"index": "original_order"})
#
# File c:\Users\amirg\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\amirg\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\amirg\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\amirg\miniconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\amirg\miniconda3\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/shark_attack_cleaned.csv'

# %%
def standardize_species(species):
    if not isinstance(species, str):
        return 'Unknown'
    species = str(species.lower())
    
    # Comprehensive list of common shark species for extraction
    common_species = [
        ('white', ['white', 'great white']),
        ('tiger', ['tiger']),
        ('nurse', ['nurse', 'grey nurse']),
        ('blue', ['blue', 'blue pointer', 'blue pointers']),
        ('blacktip', ['blacktip', 'black-tipped',]),
        ('mako', ['mako']),
        ('whitetip', ['whitetip', 'white tip']),
        ('bronze whaler', ['bronze whaler']),
        ('lemon', ['lemon']),
        ('bull', ['bull']),
        ('hammerhead', ['hammerhead', 'large hammerhead']),
        ('silvertip', ['silvertip', 'silver tip']),
        ('galapagos', ['galapagos']),
        ('sevengill', ['sevengill', 'seven-gill', 'broadnose sevengill']),
        ('wobbegong', ['wobbegong', 'wobbegongs']),
        ('shovelnose', ['shovelnose', 'shovel nose']),
        ('guitarfish', ['guitarfish', 'shovelnose guitarfish']),
        ('porbeagle', ['porbeagle']),
        ('angel', ['angel']),
        ('caribbean reef', ['caribbean reef'])
    ]
    
    for shark_standard, shark_variants in common_species:
        for variant in shark_variants:
            if variant in species:
                return shark_standard.capitalize() + " shark"
    
    
    return 'Unknown'

df['cleaned_species'] = df['species'].apply(standardize_species)
df
# Out:
#       original_order case_number         date cleaned_date    year  \
# 0                  1     ND.0001    1845-1853          NaN     0.0
# 1                  2     ND.0002    1883-1889          NaN     0.0
# 2                  3     ND.0003    1900-1905          NaN     0.0
# 3                  4     ND.0004  Before 1903          NaN     0.0
# 4                  5     ND.0005  Before 1903          NaN     0.0
# ...              ...         ...          ...          ...     ...
# 6297            6298  2018.06.04  04-Jun-2018   2018-06-04  2018.0
# 6298            6299  2018.06.08  08-Jun-2018   2018-06-08  2018.0
# 6299            6300  2018.06.09  09-Jun-2018   2018-06-09  2018.0
# 6300            6301  2018.06.18  18-Jun-2018   2018-06-18  2018.0
# 6301            6302  2018.06.25  25-Jun-2018   2018-06-25  2018.0
#
#             type             country               area  \
# 0     Unprovoked  CEYLON (SRI LANKA)   Eastern Province
# 1     Unprovoked              PANAMA                NaN
# 2     Unprovoked                 USA     North Carolina
# 3     Unprovoked           AUSTRALIA  Western Australia
# 4     Unprovoked           AUSTRALIA  Western Australia
# ...          ...                 ...                ...
# 6297    Provoked              MEXICO             Colima
# 6298  Unprovoked           AUSTRALIA    New South Wales
# 6299     Invalid                 USA             Hawaii
# 6300  Unprovoked                 USA            Georgia
# 6301        Boat                 USA         California
#
#                                  location      activity  ...  age  \
# 0     Below the English fort, Trincomalee      Swimming  ...   15
# 1                  Panama Bay 8ÂºN, 79ÂºW           NaN  ...  NaN
# 2                          Ocracoke Inlet      Swimming  ...  NaN
# 3                                     NaN  Pearl diving  ...  NaN
# 4                             Roebuck Bay        Diving  ...  NaN
# ...                                   ...           ...  ...  ...
# 6297                             La Ticla   Free diving  ...  NaN
# 6298                   Arrawarra Headland       Surfing  ...  NaN
# 6299                         Habush, Oahu       Surfing  ...   48
# 6300       St. Simon Island, Glynn County      Standing  ...   11
# 6301          Oceanside, San Diego County      Paddling  ...   57
#
#                                                  injury fatal_(y/n)  \
# 0     FATAL. "Shark bit him in half, carrying away t...           Y
# 1                                                 FATAL           Y
# 2                                                 FATAL           Y
# 3                                                 FATAL           Y
# 4                                                 FATAL           Y
# ...                                                 ...         ...
# 6297  Lacerations to leg & hand shark PROVOKED INCIDENT           N
# 6298                          Minor injury to lower leg           N
# 6299       Injury to left lower leg from surfboard skeg           N
# 6300                         Minor injury to left thigh           N
# 6301  No injury to occupant, outrigger canoe and pad...           N
#
#                time          species                 investigator_or_source  \
# 0               NaN              NaN                             S.W. Baker
# 1               NaN              NaN                    The Sun, 10/20/1938
# 2               NaN              NaN   F. Schwartz, p.23; C. Creswell, GSAF
# 3               NaN              NaN  H. Taunton; N. Bartlett,  pp. 233-234
# 4               NaN              NaN       H. Taunton; N. Bartlett,  p. 234
# ...             ...              ...                                    ...
# 6297            NaN  Tiger shark, 3m                              A .Kipper
# 6298            NaN        2 m shark                         B. Myatt, GSAF
# 6299          07h45              NaN         K.McMurray, TrackingSharks.com
# 6300  14h00  -15h00              NaN         K.McMurray, TrackingSharks.com
# 6301          18h00      White shark                       R. Collier, GSAF
#
#                                  pdf  \
# 0                 ND-0001-Ceylon.pdf
# 1         ND-0002-JulesPatterson.pdf
# 2     ND-0003-Ocracoke_1900-1905.pdf
# 3                  ND-0004-Ahmun.pdf
# 4             ND-0005-RoebuckBay.pdf
# ...                              ...
# 6297            2018.06.04-Ramos.pdf
# 6298        2018.06.08-Arrawarra.pdf
# 6299           2018.06.09-Denges.pdf
# 6300          2018.06.18-McNeely.pdf
# 6301            2018.06.25-Wolfe.pdf
#
#                                            href_formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href cleaned_species
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# ...                                                 ...             ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...     Tiger shark
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...         Unknown
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...     White shark
#
# [6302 rows x 22 columns]

# %%
species_counts = df['cleaned_species'].value_counts()

species_counts = species_counts[species_counts.index != 'Unknown']

species_counts.plot(kind='bar', figsize=(10,7))
plt.title('Distribution of Shark Attacks by Species')
plt.xlabel('Shark Species')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
for index, value in enumerate(species_counts):
    plt.text(index, value + 8, str(value), ha='center')
plt.show()

# %%
from matplotlib.pyplot import xlabel
species_counts = df['cleaned_species'].value_counts().head(10)

species_counts = species_counts[species_counts.index != 'Unknown']

species_counts.plot(kind='bar', figsize=(10,7))
plt.title('Distribution of Shark Attacks by Top 10 Species')
plt.xlabel('Shark Species')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
for index, value in enumerate(species_counts):
    plt.text(index, value + 8, str(value), ha='center')
plt.show()

# %%
top_species_counts = species_counts.head(10)

plt.figure(figsize=(10,7))
top_species_counts.plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Shark Attacks by Top 10 Species')
plt.ylabel('') 
plt.show()

# %%
df_filtered_unkown = df[df['fatal_(y/n)'] != 'Unknown']
fatal_counts = df_filtered_unkown.groupby(["cleaned_species", 'fatal_(y/n)']).size().unstack(fill_value=0)
fatal_counts = fatal_counts[fatal_counts.index != 'Unknown']
# Sort the data by total attacks for better visualization
fatal_counts['total'] = fatal_counts.sum(axis=1)
fatal_counts = fatal_counts.sort_values('total', ascending=False).drop(columns='total')

# Plotting
fatal_counts.head(10).plot(kind='bar', stacked=False, figsize=(12,7))
plt.title('Fatality of Shark Attacks by Top 10 Species')
plt.xlabel('Shark Species')
plt.ylabel('Number of Attacks')
plt.xticks(rotation=45)
plt.legend(title='Fatal')
plt.show()

# %%
surfing_related = df[df['activity'].str.contains('surfing|wave|surf|surfer', case=False, na=False)]
paddleboarding_related = df[df['activity'].str.contains('paddle|board|paddleboard', case=False, na=False)]

# Number of fatalities and non-fatalities for surfing
surfing_fatal = len(surfing_related[surfing_related['fatal_(y/n)'] == 'Y'])
surfing_non_fatal = len(surfing_related[surfing_related['fatal_(y/n)'] == 'N'])

# Number of fatalities and non-fatalities for paddleboarding
paddleboarding_fatal = len(paddleboarding_related[paddleboarding_related['fatal_(y/n)'] == 'Y'])
paddleboarding_non_fatal = len(paddleboarding_related[paddleboarding_related['fatal_(y/n)'] == 'N'])

# Data for pie chart for surfing
labels_surfing = ['Fatal', 'Non-Fatal']
sizes_surfing = [surfing_fatal, surfing_non_fatal]
explode = (0.1, 0)  

# Data for pie chart for paddleboarding
labels_paddleboarding = ['Fatal', 'Non-Fatal']
sizes_paddleboarding = [paddleboarding_fatal, paddleboarding_non_fatal]

# Plotting pie chart for surfing
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.pie(sizes_surfing, explode=explode, labels=labels_surfing,  autopct='%1.1f%%', startangle=140)
plt.title(f'Shark Attack Outcomes for Surfers (Total: {surfing_fatal + surfing_non_fatal})')

# Plotting pie chart for paddleboarding
plt.subplot(1, 2, 2)
plt.pie(sizes_paddleboarding, explode=explode, labels=labels_paddleboarding, autopct='%1.1f%%',  startangle=140)
plt.title(f'Shark Attack Outcomes for Paddleboarders (Total: {paddleboarding_fatal + paddleboarding_non_fatal})')

# Displaying the pie charts
plt.tight_layout()
plt.show()
